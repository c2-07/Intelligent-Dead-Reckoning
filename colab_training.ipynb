# %% [markdown]
# # Intelligent Dead Reckoning - Training & Evaluation
# This notebook automatically sets up the environment, clones the repository, trains the ResNet-BiLSTM model, and evaluates it.

# %%
# !git clone https://github.com/c2-07/Intelligent-Dead-Reckoning-SIH.git
# %cd Intelligent-Dead-Reckoning-SIH
# !git lfs install
# !git lfs pull
# !pip install uv
# !uv pip install -e . --system

# %%
# Train the model (automatically downloads the dataset if not already present via scripts/colab_setup.py or dataset logic)
# !uv run scripts/train.py

# %%
# Evaluate the model
# !uv run scripts/evaluate.py --model models/resnet_bilstm_latest.pth
